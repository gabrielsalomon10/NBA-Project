# %%
import pandas as pd

# %%
df = pd.read_csv("common_player_info.csv")
df.head(5)
# Out:
#    person_id first_name     last_name   display_first_last  \
# 0      76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1      76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 2       1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
# 3        949    Shareef   Abdur-Rahim  Shareef Abdur-Rahim
# 4      76005        Tom     Abernethy        Tom Abernethy
#
#   display_last_comma_first  display_fi_last          player_slug  \
# 0          Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1     Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 2       Abdul-Wahad, Tariq   T. Abdul-Wahad    tariq-abdul-wahad
# 3     Abdur-Rahim, Shareef   S. Abdur-Rahim  shareef-abdur-rahim
# 4           Abernethy, Tom     T. Abernethy        tom-abernethy
#
#              birthdate          school country  ...  \
# 0  1968-06-24 00:00:00            Duke     USA  ...
# 1  1947-04-16 00:00:00            UCLA     USA  ...
# 2  1974-11-03 00:00:00  San Jose State  France  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4171 entries, 0 to 4170
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   person_id                         4171 non-null   int64
#  1   first_name                        4171 non-null   object
#  2   last_name                         4171 non-null   object
#  3   display_first_last                4171 non-null   object
#  4   display_last_comma_first          4171 non-null   object
#  5   display_fi_last                   4171 non-null   object
#  6   player_slug                       4171 non-null   object
#  7   birthdate                         4171 non-null   object
#  8   school                            4156 non-null   object
#  9   country                           4170 non-null   object
#  10  last_affiliation                  4171 non-null   object
# ...

# %%
#Expresa el porcentaje de valores nulos de cada columna
missingData = df.isnull().mean() * 100
print(missingData[missingData > 0].sort_values(ascending=False))
# Out:
# jersey               23.495565
# team_name            16.830496
# team_abbreviation    16.830496
# team_code            16.830496
# team_city            16.830496
# draft_number          5.346440
# draft_round           3.931911
# weight                2.397507
# height                2.301606
# position              1.510429
# school                0.359626
# from_year             0.359626
# to_year               0.359626
# country               0.023975
# playercode            0.023975
# dtype: float64

# %%
df.shape
# Out:
# (4171, 33)

# %%
dfEliminados = df.drop(["first_name", "last_name", "display_last_comma_first", "display_fi_last", "player_slug", "last_affiliation", "dleague_flag", "nba_flag", "games_played_flag", "draft_year", "draft_round", "draft_number", "team_abbreviation", "team_code", "team_city", "playercode", "from_year", "to_year" ], axis=1)
dfEliminados.head(5)
# Out:
#    person_id   display_first_last            birthdate          school  \
# 0      76001       Alaa Abdelnaby  1968-06-24 00:00:00            Duke
# 1      76003  Kareem Abdul-Jabbar  1947-04-16 00:00:00            UCLA
# 2       1505    Tariq Abdul-Wahad  1974-11-03 00:00:00  San Jose State
# 3        949  Shareef Abdur-Rahim  1976-12-11 00:00:00      California
# 4      76005        Tom Abernethy  1954-05-06 00:00:00         Indiana
#
#   country height  weight  season_exp jersey       position rosterstatus  \
# 0     USA   6-10   240.0         5.0     30        Forward     Inactive
# 1     USA    7-2   225.0        20.0     33         Center     Inactive
# 2  France    6-6   235.0         7.0      9  Forward-Guard     Inactive
# 3     USA    6-9   245.0        13.0      3        Forward     Inactive
# 4     USA    6-7   220.0         5.0      5        Forward     Inactive
#
#   games_played_current_season_flag     team_id      team_name greatest_75_flag
# ...

# %%
#Cambiamos el nombre de la columna
dfEliminados = dfEliminados.rename(columns={'display_first_last': 'player_name'})
dfEliminados.head(5)
# Out:
#    person_id          player_name            birthdate          school  \
# 0      76001       Alaa Abdelnaby  1968-06-24 00:00:00            Duke
# 1      76003  Kareem Abdul-Jabbar  1947-04-16 00:00:00            UCLA
# 2       1505    Tariq Abdul-Wahad  1974-11-03 00:00:00  San Jose State
# 3        949  Shareef Abdur-Rahim  1976-12-11 00:00:00      California
# 4      76005        Tom Abernethy  1954-05-06 00:00:00         Indiana
#
#   country height  weight  season_exp jersey       position rosterstatus  \
# 0     USA   6-10   240.0         5.0     30        Forward     Inactive
# 1     USA    7-2   225.0        20.0     33         Center     Inactive
# 2  France    6-6   235.0         7.0      9  Forward-Guard     Inactive
# 3     USA    6-9   245.0        13.0      3        Forward     Inactive
# 4     USA    6-7   220.0         5.0      5        Forward     Inactive
#
#   games_played_current_season_flag     team_id      team_name greatest_75_flag
# ...

# %%
#Cambiamos el tipo de dato de season_exp
dfEliminados["season_exp"] = dfEliminados["season_exp"].astype(int)
dfEliminados.head(5)
# Out:
#    person_id          player_name            birthdate          school  \
# 0      76001       Alaa Abdelnaby  1968-06-24 00:00:00            Duke
# 1      76003  Kareem Abdul-Jabbar  1947-04-16 00:00:00            UCLA
# 2       1505    Tariq Abdul-Wahad  1974-11-03 00:00:00  San Jose State
# 3        949  Shareef Abdur-Rahim  1976-12-11 00:00:00      California
# 4      76005        Tom Abernethy  1954-05-06 00:00:00         Indiana
#
#   country height  weight  season_exp jersey       position rosterstatus  \
# 0     USA   6-10   240.0           5     30        Forward     Inactive
# 1     USA    7-2   225.0          20     33         Center     Inactive
# 2  France    6-6   235.0           7      9  Forward-Guard     Inactive
# 3     USA    6-9   245.0          13      3        Forward     Inactive
# 4     USA    6-7   220.0           5      5        Forward     Inactive
#
#   games_played_current_season_flag     team_id      team_name greatest_75_flag
# ...

# %%
dfEliminados.shape
# Out:
# (4171, 15)
