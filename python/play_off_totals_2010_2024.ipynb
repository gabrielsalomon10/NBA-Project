# %%
import pandas as pd

# %%
df = pd.read_csv("play_off_totals_2010_2024.csv")
df.head(5)
# Out:
#   SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME   GAME_ID  \
# 0     2010-11  1610612737               ATL  Atlanta Hawks  41000205
# 1     2010-11  1610612737               ATL  Atlanta Hawks  41000201
# 2     2010-11  1610612737               ATL  Atlanta Hawks  41000202
# 3     2010-11  1610612737               ATL  Atlanta Hawks  41000132
# 4     2010-11  1610612737               ATL  Atlanta Hawks  41000135
#
#              GAME_DATE    MATCHUP WL   MIN  FGM  ...  AST_RANK  TOV_RANK  \
# 0  2011-05-10T00:00:00  ATL @ CHI  L  48.0   34  ...        43        32
# 1  2011-05-02T00:00:00  ATL @ CHI  W  48.0   40  ...        43        16
# 2  2011-05-04T00:00:00  ATL @ CHI  L  48.0   26  ...       137        51
# 3  2011-04-19T00:00:00  ATL @ ORL  L  48.0   32  ...       123       107
# 4  2011-04-26T00:00:00  ATL @ ORL  L  48.0   25  ...       123        63
#
#    STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2362 entries, 0 to 2361
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SEASON_YEAR        2362 non-null   object
#  1   TEAM_ID            2362 non-null   int64
#  2   TEAM_ABBREVIATION  2362 non-null   object
#  3   TEAM_NAME          2362 non-null   object
#  4   GAME_ID            2362 non-null   int64
#  5   GAME_DATE          2362 non-null   object
#  6   MATCHUP            2362 non-null   object
#  7   WL                 2362 non-null   object
#  8   MIN                2362 non-null   float64
#  9   FGM                2362 non-null   int64
#  10  FGA                2362 non-null   int64
#  11  FG_PCT             2362 non-null   float64
#  12  FG3M               2362 non-null   int64
#  13  FG3A               2362 non-null   int64
#  14  FG3_PCT            2362 non-null   float64
#  15  FTM                2362 non-null   int64
# ...

# %%
df["SEASON_YEAR"]
# Out:
# 0       2010-11
# 1       2010-11
# 2       2010-11
# 3       2010-11
# 4       2010-11
#          ...
# 2357    2023-24
# 2358    2023-24
# 2359    2023-24
# 2360    2023-24
# 2361    2023-24
# Name: SEASON_YEAR, Length: 2362, dtype: object

# %%
df.shape
# Out:
# (2362, 57)

# %%
fechaSeleccionada = df[df["SEASON_YEAR"] == "2022-23"]
fechaSeleccionada
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION         TEAM_NAME   GAME_ID  \
# 2008     2022-23  1610612737               ATL     Atlanta Hawks  42200115
# 2009     2022-23  1610612737               ATL     Atlanta Hawks  42200112
# 2010     2022-23  1610612737               ATL     Atlanta Hawks  42200111
# 2011     2022-23  1610612751               BKN     Brooklyn Nets  42200121
# 2012     2022-23  1610612751               BKN     Brooklyn Nets  42200122
# ...          ...         ...               ...               ...       ...
# 2171     2022-23  1610612756               PHX      Phoenix Suns  42200175
# 2172     2022-23  1610612758               SAC  Sacramento Kings  42200162
# 2173     2022-23  1610612758               SAC  Sacramento Kings  42200165
# 2174     2022-23  1610612758               SAC  Sacramento Kings  42200167
# 2175     2022-23  1610612758               SAC  Sacramento Kings  42200161
#
# ...

# %%
fechaSeleccionada.shape
# Out:
# (168, 57)

# %%
fechaSeleccionada.to_csv("play_off_totals_2010_2024_sql.csv")
