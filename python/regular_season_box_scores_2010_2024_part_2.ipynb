# %%
import pandas as pd

# %%
df = pd.read_csv("regular_season_box_scores_2010_2024_part_2.csv")
df.head(5)
# Out:
#   season_year   game_date    gameId      matchup      teamId teamCity  \
# 0     2010-11  2010-12-11  21000347  HOU vs. CLE  1610612745  Houston
# 1     2010-11  2010-11-19  21000173    HOU @ TOR  1610612745  Houston
# 2     2011-12  2012-03-18  21100667    HOU @ PHX  1610612745  Houston
# 3     2010-11  2010-12-22  21000429    HOU @ LAC  1610612745  Houston
# 4     2010-11  2011-02-22  21000840    HOU @ DET  1610612745  Houston
#
#   teamName teamTricode teamSlug  personId  ... reboundsOffensive  \
# 0  Rockets         HOU  rockets      2449  ...                 6
# 1  Rockets         HOU  rockets      2449  ...                 1
# 2  Rockets         HOU  rockets      2449  ...                 3
# 3  Rockets         HOU  rockets      2449  ...                 1
# 4  Rockets         HOU  rockets      2449  ...                 3
#
#   reboundsDefensive reboundsTotal  assists steals  blocks  turnovers  \
# 0                 8            14        1      1       0          4
# ...

# %%
df.shape
# Out:
# (141493, 34)

# %%
fechaSeleccionada = df[df["season_year"] == "2022-23"]
fechaSeleccionada
# Out:
#        season_year   game_date    gameId      matchup      teamId  teamCity  \
# 2500       2022-23  2023-01-28  22200743    HOU @ DET  1610612745   Houston
# 2522       2022-23  2023-01-08  22200601  HOU vs. MIN  1610612745   Houston
# 2523       2022-23  2022-12-13  22200411  HOU vs. PHX  1610612745   Houston
# 2538       2022-23  2023-01-15  22200649    HOU @ LAC  1610612745   Houston
# 2546       2022-23  2022-10-26  22200063    HOU @ UTA  1610612745   Houston
# ...            ...         ...       ...          ...         ...       ...
# 140856     2022-23  2022-10-21  22200023  NYK vs. DET  1610612752  New York
# 140857     2022-23  2023-03-31  22201154    NYK @ CLE  1610612752  New York
# 140858     2022-23  2023-02-24  22200895    NYK @ WAS  1610612752  New York
# 140859     2022-23  2023-04-05  22201190    NYK @ IND  1610612752  New York
# 140860     2022-23  2023-04-02  22201168  NYK vs. WAS  1610612752  New York
#
# ...

# %%
fechaSeleccionada.shape
# Out:
# (10591, 34)

# %%
fechaSeleccionada.to_csv("regular_season_box_scores_2010_2024_part_2_sql.csv")
