# %%
import pandas as pd

# %%
df = pd.read_csv("regular_season_box_scores_2010_2024_part_3.csv")
df.head()
# Out:
#   season_year   game_date    gameId      matchup      teamId       teamCity  \
# 0     2015-16  2016-02-25  21500857    OKC @ NOP  1610612760  Oklahoma City
# 1     2017-18  2017-12-07  21700365    OKC @ BKN  1610612760  Oklahoma City
# 2     2012-13  2012-12-31  21200456  OKC vs. PHX  1610612760  Oklahoma City
# 3     2013-14  2013-12-29  21300450  OKC vs. HOU  1610612760  Oklahoma City
# 4     2017-18  2017-12-16  21700431    OKC @ NYK  1610612760  Oklahoma City
#
#   teamName teamTricode teamSlug  personId  ... reboundsOffensive  \
# 0  Thunder         OKC  thunder      2555  ...                 0
# 1  Thunder         OKC  thunder      2555  ...                 2
# 2  Thunder         OKC  thunder      2555  ...                 4
# 3  Thunder         OKC  thunder      2555  ...                 1
# 4  Thunder         OKC  thunder      2555  ...                 0
#
#   reboundsDefensive reboundsTotal  assists steals  blocks  turnovers  \
# ...

# %%
df.shape
# Out:
# (141492, 34)

# %%
fechaSeleccionada = df[df["season_year"] == "2022-23"]
fechaSeleccionada
# Out:
#        season_year   game_date    gameId      matchup      teamId  \
# 7076       2022-23  2023-02-01  22200773    OKC @ HOU  1610612760
# 7077       2022-23  2022-11-07  22200146    OKC @ DET  1610612760
# 7078       2022-23  2023-01-08  22200602  OKC vs. DAL  1610612760
# 7091       2022-23  2022-11-03  22200119  OKC vs. DEN  1610612760
# 7093       2022-23  2022-11-21  22200254  OKC vs. NYK  1610612760
# ...            ...         ...       ...          ...         ...
# 141405     2022-23  2023-03-22  22201083  WAS vs. DEN  1610612764
# 141406     2022-23  2023-04-09  22201222  WAS vs. HOU  1610612764
# 141407     2022-23  2023-03-21  22201077    WAS @ ORL  1610612764
# 141408     2022-23  2023-04-04  22201179  WAS vs. MIL  1610612764
# 141409     2022-23  2023-04-05  22201191    WAS @ ATL  1610612764
#
#              teamCity teamName teamTricode teamSlug  personId  ...  \
# 7076    Oklahoma City  Thunder         OKC  thunder    203488  ...
# ...

# %%
fechaSeleccionada.shape
# Out:
# (10539, 34)

# %%
fechaSeleccionada.to_csv("regular_season_box_scores_2010_2024_part_3_sql.csv")
